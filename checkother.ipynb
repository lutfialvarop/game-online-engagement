# %%
import pandas as pd

# %%
df = pd.read_csv('./online_gaming_insights.csv')

# %%
percent = df['Location'].value_counts(normalize=True).get('Asia', 0) * 100
print(f"{percent:.2f}%")
# Out:
# 20.22%
